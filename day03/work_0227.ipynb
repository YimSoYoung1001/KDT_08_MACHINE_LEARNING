# %% [markdown]
# - age : age in years
# - sex
# - bmi : body mass index
# - bp : average blood pressure
# - s1 tc : total serum cholesterol
# - s2 ldl : low-density lipoproteins
# - s3 hdl : high-density lipoproteins
# - s4 tch : total cholesterol / HDL => 증가할수록 심혈관질환 발생빈도 증가 (보통 수치가 3 ~ 7 정도로 나옴)
# - s5 ltg : possibly log of serum triglycerides level
# - s6 glu : blood sugar level

# %% [markdown]
# ### 전처리
# - 이상치를 제거하니까 score 값이 감소했다. 왜그럴까?? => 무조건 제거하면 안된다! 데이터를 보고 제거를 할지, 아님 따로 빼서 다른 모델로 따로 만들지, 아님 다른 값으로 대체할지 등등 여러 방법이 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsRegressor

# %%
file = '../data/diabetes.csv'
data = pd.read_csv(file, index_col = [0])
data
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %%
data.isna().sum()
#결측치 없음
# Out:
# AGE    0
# SEX    0
# BMI    0
# BP     0
# S1     0
# S2     0
# S3     0
# S4     0
# S5     0
# S6     0
# Y      0
# dtype: int64

# %%
data.duplicated().sum()
# 중복값 없음
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AGE     442 non-null    int64
#  1   SEX     442 non-null    int64
#  2   BMI     442 non-null    float64
#  3   BP      442 non-null    float64
#  4   S1      442 non-null    int64
#  5   S2      442 non-null    float64
#  6   S3      442 non-null    float64
#  7   S4      442 non-null    float64
#  8   S5      442 non-null    float64
#  9   S6      442 non-null    int64
#  10  Y       442 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 41.4 KB

# %%
data.columns = ['age', 'sex', 'bmi', 'bp', 'tc', 'ldl', 'hdl', 'tch', 'ltg', 'glu', 'target']
data
# Out:
#      age  sex   bmi      bp   tc    ldl   hdl   tch     ltg  glu  target
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87     151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69      75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85     141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89     206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80     135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...     ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93     178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102     104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95     132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85     220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92      57
#
# [442 rows x 11 columns]

# %%
result = data.corr()
result
# Out:
#              age       sex       bmi        bp        tc       ldl       hdl  \
# age     1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex     0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi     0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp      0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# tc      0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# ldl     0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# hdl    -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# tch     0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# ltg     0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# glu     0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# target  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#              tch       ltg       glu    target
# age     0.203841  0.270774  0.301731  0.187889
# sex     0.332115  0.149916  0.208133  0.043062
# bmi     0.413807  0.446157  0.388680  0.586450
# bp      0.257650  0.393480  0.390430  0.441482
# tc      0.542207  0.515503  0.325717  0.212022
# ldl     0.659817  0.318357  0.290600  0.174054
# hdl    -0.738493 -0.398577 -0.273697 -0.394789
# tch     1.000000  0.617859  0.417212  0.430453
# ltg     0.617859  1.000000  0.464669  0.565883
# glu     0.417212  0.464669  1.000000  0.382483
# target  0.430453  0.565883  0.382483  1.000000

# %%
result['target']
# Out:
# age       0.187889
# sex       0.043062
# bmi       0.586450
# bp        0.441482
# tc        0.212022
# ldl       0.174054
# hdl      -0.394789
# tch       0.430453
# ltg       0.565883
# glu       0.382483
# target    1.000000
# Name: target, dtype: float64

# %%
result['target'].abs().sort_values(ascending=False)
# 상관관계를 분석하니 bmi와 ltg가 가장 높은 상관관계를 보였다. 이걸 시각화로도 확인해보자
# Out:
# target    1.000000
# bmi       0.586450
# ltg       0.565883
# bp        0.441482
# tch       0.430453
# hdl       0.394789
# glu       0.382483
# tc        0.212022
# age       0.187889
# ldl       0.174054
# sex       0.043062
# Name: target, dtype: float64

# %%
# for i in data.columns:
#     y_list = data[i]
#     print(y_list)
low_num = data.shape[0]

target_list = []
for i in range(low_num):
    target_list.append(data['target'][i])
#print(target_list)
print(len(target_list))

for col in data.columns:
    for_data = data[col]
    x_list = []
    for i in range(low_num):
        x_list.append(for_data[i])
    plt.scatter(x_list, target_list)
    plt.xlabel(col)
    plt.ylabel('target')
    plt.title(f"{col} & target")
    plt.show()

# 시각화를 해보니 상관성이 보인다. 그래서 bmi, ltg를 피쳐로 하기로 결정했다.
# Out:
# 442

# %%
use_data = data[['bmi','ltg','target']]
use_data
# Out:
#       bmi     ltg  target
# 0    32.1  4.8598     151
# 1    21.6  3.8918      75
# 2    30.5  4.6728     141
# 3    25.3  4.8903     206
# 4    23.0  4.2905     135
# ..    ...     ...     ...
# 437  28.2  4.9836     178
# 438  24.9  4.4427     104
# 439  24.9  4.1271     132
# 440  30.0  5.1299     220
# 441  19.6  4.5951      57
#
# [442 rows x 3 columns]

# %% [markdown]
# ### 피처, 타겟 분리

# %%
featureDF = use_data[['bmi','ltg']]
featureDF.head()
# Out:
#     bmi     ltg
# 0  32.1  4.8598
# 1  21.6  3.8918
# 2  30.5  4.6728
# 3  25.3  4.8903
# 4  23.0  4.2905

# %%
targetDF = use_data['target']
targetDF.head()
# Out:
# 0    151
# 1     75
# 2    141
# 3    206
# 4    135
# Name: target, dtype: int64

# %% [markdown]
# ### 학습/테스트 데이터셋 분리
# - 학습 : 테스트 = 80:20

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(featureDF, targetDF, test_size = 0.2, random_state = 75)

# %%
# 학습 및 테스트 데이터셋 확인
print('학습용 데이터 셋')
print(f"X_train.shape: {X_train.shape} \ny_train.shape: {y_train.shape}")
print('테스트용 데이터 셋')
print(f"X_test.shape: {X_test.shape} \ny_test.shape: {y_test.shape}")
# Out:
# 학습용 데이터 셋
# X_train.shape: (353, 2)
# y_train.shape: (353,)
# 테스트용 데이터 셋
# X_test.shape: (89, 2)
# y_test.shape: (89,)

# %% [markdown]
# ### 피처 스케일링

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaled_X_train = scaler.transform(X_train)
scaled_X_train.shape
# Out:
# (353, 2)

# %%
scaled_X_test = scaler.transform(X_test)
scaled_X_test.shape
# Out:
# (89, 2)

# %%
# 피쳐 스케일링이 제대로 되었는지 시각화 해보자
# 원본 데이터 시각화
plt.scatter(X_train['bmi'], X_train["ltg"], c='red')
plt.xlabel('bmi')
plt.ylabel('ltg')
plt.show()

# %%
# 스케일링 된 데이터 시각화
plt.scatter(scaled_X_train[:,0], scaled_X_train[:,1], c = 'blue')
plt.xlabel('bmi')
plt.ylabel('ltg')
plt.show()

# 스케일링이 잘 된것을 확인하였다.

# %% [markdown]
# ### 학습

# %%
max_k = scaled_X_train.shape[0]
max_k
# Out:
# 353

# %%
train_scoreList = []
test_scoreList = []
for k in range(1, max_k):
    #학습 진행
    sample_model = KNeighborsRegressor(n_neighbors = k)
    sample_model.fit(scaled_X_train, y_train)
    # 검사
    train_scoreList.append(sample_model.score(scaled_X_train, y_train))
    test_scoreList.append(sample_model.score(scaled_X_test, y_test))

# 전체 점수 리스트 확인
print(f"Train score : \n{train_scoreList}")
print(f"Test score : \n{test_scoreList}")
# Out:
# Train score :
# [0.9914700099626836, 0.7440291997509965, 0.6387971553054257, 0.609353603772608, 0.594553310047081, 0.5635970629357894, 0.5425558373100534, 0.5319617844680513, 0.5234031490109295, 0.515022557392393, 0.5077262216710956, 0.4969983872415361, 0.49722026294253185, 0.4982281950908535, 0.492134293331682, 0.4883723573886466, 0.4819645464482001, 0.4802016023765058, 0.48658731652594267, 0.48250892546585067, 0.4809153146804235, 0.47469520703752555, 0.4700274501656031, 0.4663781934145105, 0.46705205864707167, 0.46673120813242586, 0.468045155343045, 0.4650782867174199, 0.4611338351872466, 0.4607447922350575, 0.4606494141077454, 0.4596429703035928, 0.45972481311449076, 0.45744453225284476, 0.45779736732000575, 0.45317983360704817, 0.4504851113973851, 0.450257749613615, 0.4516333916005134, 0.44904562175183194, 0.44700354161607303, 0.44617719256815724, 0.4455399575819057, 0.4444141488503026, 0.4429738352741954, 0.44053797129748584, 0.4385282832298807, 0.43865534680132734, 0.43713513799000936, 0.4344689002989969, 0.4336935682593738, 0.4331298522273931, 0.43145666839398467, 0.4335353859290586, 0.4326287080576857, 0.43204040282683875, 0.431651494616608, 0.4312691121356087, 0.431183093495233, 0.43048322781622694, 0.4308295113204912, 0.429858368746281, 0.43099036352697695, 0.433048659508815, 0.43232901976551963, 0.4332808266799807, 0.43177805571561445, 0.43448554250318605, 0.4333600532847425, 0.4352188759529021, 0.43353323055976534, 0.4336043740088501, 0.43212220811202096, 0.4313945823826236, 0.4298019447782697, 0.4301126420209652, 0.4278897544712481, 0.4282368905943785, 0.42793941931599844, 0.42645431786733135, 0.4258012806566287, 0.4250554827670243, 0.4230154631560289, 0.42147732501261026, 0.42051906743408884, 0.42049389442914153, 0.42156353342190267, 0.4229572863579788, 0.4218613216645649, 0.4219528581630486, 0.4235260611437641, 0.42343174948034323, 0.42413197218739196, 0.42310601795710123, 0.42259758141322046, 0.4208373929443312, 0.4199964616648678, 0.4176287948888716, 0.41696993751231093, 0.4167539709542466, 0.4169612749848921, 0.41734637999280233, 0.4170749098658255, 0.4167711639799583, 0.41643629696387885, 0.41610601314977236, 0.4161699496757718, 0.41619162436958057, 0.41642757997684177, 0.4146769773602428, 0.41368784044440343, 0.41245727422568, 0.4121315544882036, 0.4117830810932448, 0.4114248410569914, 0.4116166756063042, 0.4103882995561663, 0.41008041359852365, 0.4086829021070103, 0.40807014740379066, 0.4082943911577004, 0.4075196750383412, 0.40647231879222323, 0.40616473326109004, 0.4057902457680752, 0.40582368059502183, 0.40430719106585766, 0.4029093074842065, 0.4009215462137351, 0.40049900080028755, 0.40061374977976016, 0.39859484983975657, 0.39738919064072986, 0.3972816175635716, 0.3952539088850874, 0.3949687996273542, 0.39410691751791294, 0.39399969143341573, 0.3924043512929629, 0.3931820930152704, 0.3930381170989523, 0.39234491994887233, 0.3916343388203978, 0.39121935361420734, 0.3895345239794302, 0.3880924470883397, 0.386793959754147, 0.3863068971719993, 0.3845359204699237, 0.38396696791637164, 0.3831563893893858, 0.3817591275584974, 0.38113827191625615, 0.38058487881508285, 0.37902041014403365, 0.37871617817167, 0.3784707100005751, 0.3767800223047404, 0.3758175191415033, 0.3752439812582826, 0.37365437875314245, 0.37368167395390506, 0.37309202400258734, 0.37228615834229406, 0.37148208660269466, 0.36994828179255, 0.36848145644916275, 0.36705845604057885, 0.3669095682515865, 0.36581623082802184, 0.36526832457104996, 0.36472767625891567, 0.3631347133287739, 0.3620093085601952, 0.36129859931125774, 0.3602379709535959, 0.3606010472757908, 0.3591376765149018, 0.35800442190976167, 0.35717439169956533, 0.35476964535612554, 0.3534490778604369, 0.3513062228496244, 0.35028528657096547, 0.34901026611575825, 0.3478196363304531, 0.3463331983554352, 0.3443661732056411, 0.343208423500973, 0.3415747311314338, 0.3399793200784972, 0.33853208195136864, 0.33782725245500267, 0.3369428496493313, 0.33533442271120006, 0.33433040761372856, 0.333392889633489 ...
# Test score :
# [0.031566870397384594, 0.3021100623043823, 0.33827847933412747, 0.39995190292509286, 0.4359531190670325, 0.4742148607409916, 0.47964992659726313, 0.4906291704381419, 0.4948512581672715, 0.4879316737033803, 0.4796768592901208, 0.49732093299163704, 0.48615619944498434, 0.4921373119513456, 0.49804327977290697, 0.5079503527571465, 0.510179897223409, 0.5027910945305343, 0.5057870920541965, 0.5070070710476158, 0.5092260740188579, 0.5092002013898322, 0.510580940324054, 0.5171503097894757, 0.5158157353394697, 0.5221811374594014, 0.5170384286403349, 0.5176993779639134, 0.5192648810002203, 0.5247326121596187, 0.5245292766771148, 0.5252592916856451, 0.5223050276236445, 0.5200721817775498, 0.5219701815953993, 0.5205286155268845, 0.5203986970151676, 0.5132255614463743, 0.5168566528658518, 0.5115913797374003, 0.5093738476772791, 0.5096068802987286, 0.507969841198786, 0.5086450211010826, 0.5099733910950808, 0.5130877913047018, 0.517672538731542, 0.5157158813277505, 0.5103590250435627, 0.5088726968151265, 0.5093076939164336, 0.5098045235631852, 0.5059495834675665, 0.5045675131084084, 0.5028869530941149, 0.5020597530182047, 0.5047288797600675, 0.5056293348731917, 0.5075529906878521, 0.5094819435748172, 0.5122005972140715, 0.5134898162356143, 0.5103463908746417, 0.5106116530925406, 0.5109812802436227, 0.5119693830384356, 0.5060036086563486, 0.5067623774126433, 0.5050117575865465, 0.503070836248538, 0.5026933861319323, 0.50192026932718, 0.500445496784963, 0.5013156476636778, 0.501575901804132, 0.4993016852043284, 0.5010011986537062, 0.5019057021313855, 0.49937142552967695, 0.5010182859396553, 0.5006577634829603, 0.5007634842024007, 0.49953232767738986, 0.49935749245955674, 0.5000722800596444, 0.5008210564333351, 0.5013791121592661, 0.5014269757646908, 0.5008915542454911, 0.5002075307173649, 0.5000410899156013, 0.4974346999611148, 0.49433239895404, 0.49523646779410024, 0.49601651657151435, 0.4958277897805474, 0.49541434053276356, 0.4947537619844846, 0.4941321537587733, 0.4948755010269653, 0.4927255854868815, 0.4910577666700835, 0.4902063306018789, 0.48887203306268867, 0.4885570942436396, 0.48933647652548107, 0.4874259643514668, 0.4866709519348089, 0.4858734537138214, 0.4843763693449553, 0.4829707117497979, 0.4816214830268487, 0.48067146208014544, 0.4787162721998591, 0.48056115130728605, 0.48024027158195415, 0.47993478006693435, 0.47946034939298865, 0.4782562061190181, 0.4758280228245534, 0.47629250538839385, 0.47374650862951606, 0.47411951549111897, 0.47431266180752973, 0.4739982141511433, 0.4744477348484206, 0.4726216858217789, 0.473360798501852, 0.4720578679257843, 0.4732539929595082, 0.4721686303018525, 0.47128503445714287, 0.47075945301939914, 0.47102366518449834, 0.46967167995970294, 0.468834105484235, 0.46752590886189527, 0.46515834085313024, 0.4635255900121371, 0.4630718168327428, 0.4611970872597052, 0.4589141188618263, 0.45825737660112176, 0.45697286621950606, 0.45652214236474264, 0.45618503781420483, 0.4578702984355568, 0.4567378716565723, 0.4556199208484859, 0.4543479176454235, 0.45422261745725123, 0.45223261925697367, 0.450486778969579, 0.45021309337754356, 0.4493870207681434, 0.447875689272645, 0.44744730260331966, 0.44499459362622973, 0.44319871988046267, 0.44239538431242553, 0.44107122279303135, 0.4399880578689789, 0.43888676275597005, 0.4379927936922027, 0.43751881757425226, 0.43546605404476013, 0.43382631180555, 0.4327526441662918, 0.4324825363029331, 0.43163670691595024, 0.4302693738824327, 0.4314035389408124, 0.43117463486531116, 0.4293305107089376, 0.42805113736210365, 0.42803642145646004, 0.42481965453664283, 0.42361915167750275, 0.4220523874926032, 0.4209032070889084, 0.4200377168102106, 0.4174210540230989, 0.4155292469988845, 0.4145966038282075, 0.4116931505645005, 0.4085006997885162, 0.4062859818087238, 0.40385082938648986, 0.4010832792997443, 0.3991551331332608, 0.3979908689723398, 0.3950314989736694, 0.39370924300936594, 0.3914719446770717, 0.3897154296764853, 0.3885198035851183, 0.38846738930118074, 0.3869034353153672, 0 ...

# %%
plt.plot(train_scoreList, color = 'green', alpha = 0.5)
plt.plot(test_scoreList, color = 'red', alpha = 0.9)
plt.xlabel('k')
plt.ylabel('score')
plt.show()

# %%
max_k = test_scoreList.index(max(test_scoreList)) + 1
# +1을 해주어야 한다. 인덱스는 0에서 시작하니까
max_k
# Out:
# 32

# %%
model = KNeighborsRegressor(n_neighbors = max_k)
model
# Out:
# KNeighborsRegressor(n_neighbors=32)

# %%
model.fit(scaled_X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=32)

# %%
# 점수 확인
result_train = model.score(scaled_X_train, y_train)
result_train
# Out:
# 0.4596429703035928

# %%
result_test = model.score(scaled_X_test, y_test)
result_test
# Out:
# 0.5252592916856451

# %% [markdown]
# ###### 훈련점수와 테스트점수가 유사하므로 최적적합이라고 할수있겠다.

# %% [markdown]
# #### 예측

# %%
y_pred = model.predict(scaled_X_test)
y_pred
#예측값이 나옴
# Out:
# array([226.53125, 164.03125, 208.28125, 153.90625, 161.5    ,  83.15625,
#        221.8125 , 112.90625, 120.875  ,  84.75   , 173.71875, 124.8125 ,
#        170.90625, 177.875  , 116.09375, 150.84375, 204.25   , 191.71875,
#        108.65625, 113.78125, 175.71875, 104.5625 ,  97.65625, 112.78125,
#        111.09375, 180.84375, 153.09375, 219.5625 , 220.59375,  83.59375,
#        122.     , 191.59375, 130.3125 , 105.5    , 102.90625, 236.96875,
#        241.15625, 210.1875 , 213.90625, 219.375  , 140.90625, 146.71875,
#         80.90625, 123.25   , 116.28125,  89.78125,  87.46875, 160.40625,
#         94.9375 , 175.90625, 198.1875 ,  82.4375 , 150.15625, 151.15625,
#        113.03125, 136.0625 , 186.65625, 100.75   , 121.125  ,  96.8125 ,
#         87.46875, 250.6875 , 172.875  , 114.28125, 210.9375 ,  85.40625,
#        163.6875 , 123.46875, 243.71875, 205.9375 ,  84.6875 , 107.25   ,
#         82.84375, 125.625  , 190.     , 110.875  , 136.3125 , 175.28125,
#        131.78125, 122.53125, 228.5625 ,  84.5    , 166.09375, 244.5625 ,
#         81.78125,  91.0625 , 174.4375 , 221.65625, 189.25   ])

# %%
y_pred = y_pred.round(0)
y_pred.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 2
#       1 y_pred = y_pred.round(0)
# ----> 2 y_pred.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %% [markdown]
# #### 성능평가

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print('[ 모델설명도 ]')
print(f"설정계수값(R2) : {r2_score(y_test, y_pred)}")

# 처음에 테스트 데이터셋이 아닌 >>피쳐 데이터프레임 전체<<를 넣어버림! => 그래서 R2의 값이 마이너스의 값이 나옴 (잘못되었다는 예기)
# 그런데 R2의 값은 0~1 범위의 값이 나온다. 마이너스가 나왔다는 것은 무언가 잘못되었다는 이야기

print('[ 에러 ]')
print(f"평균제곱오차(MSE) : {mean_squared_error(y_test, y_pred)}")
print(f"평균절대값오차(MAE) : {mean_absolute_error(y_test, y_pred)}")
